# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import quad,trapezoid,simpson

# %%
# DELUPPGIFT 1
def v(t,g,w,w0):
    return np.abs(((g * w0**2)/(w0**2  - w**2) * (w0 * np.sin(w0 * t) - w * np.sin(w * t))))

# %%
w = 2 * np.pi
w0 = 3 * np.pi
g = 0.1 
t = 0
T = 10
N = 4000
time = np.linspace(t,T, N)

# %%
plt.plot(time, v(time,g,w,w0), label="Hastighet")
plt.title("Hastighet över tid för T = 10")
plt.xlabel("Tid[s]")
plt.ylabel("Hastighet [m/s]")
plt.grid()
plt.show()

# %%
I,err = quad(v,t,T, args = (g,w,w0), limit=500,epsabs=1.49e-12, epsrel=1.49e-12,)
print("Integral för T = 10:", I)
# Out:
# Integral för T = 10: 12.03274042724283
# C:\Users\benne\AppData\Local\Temp\ipykernel_7412\2279506885.py:1: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   I,err = quad(v,t,T, args = (g,w,w0), limit=500,epsabs=1.49e-12, epsrel=1.49e-12,)

# %%
T = 0.25
N = 100
time = np.linspace(t, T, N)
plt.plot(time, v(time, g, w, w0))
plt.title("Hastighet över tid för T = 0.25")
plt.xlabel("Tid [s]")
plt.ylabel("Hastighet [m/s]")
plt.grid()
plt.show()

I, err = quad(v,t,T, args = (g,w,w0), limit=500,epsabs=1.49e-12, epsrel=1.49e-12,)
print("Integral för T = 0.25:", I)
# Out:
# Integral för T = 0.25: 0.12727922061357855

# %%
# DELUPPGIFT 2
# Trapazoid
T = 10
N = 100
time = np.linspace(t,T, N)
Integrals = []
for _ in range(4):
    Integrals.append((float(trapezoid(v(time,g,w,w0), time)), float(trapezoid(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
    N *= 2
    time = np.linspace(t,T,N)
print(Integrals)
# Out:
# [(0.12726849220585393, 0.12723542520246536), (0.12727656542226934, 0.12726849220585393), (0.1272785601402751, 0.12727656542226934), (0.12727905590839245, 0.1272785601402751)]

# %%
# Simpson
T = 10
N = 100
time = np.linspace(t,T, N)
Integrals = []
for _ in range(3):
    Integrals.append((float(simpson(v(time,g,w,w0), time)), float(simpson(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
    N *= 2
    time = np.linspace(t,T,N)
print(Integrals)
# Out:
# [(0.12727922276610007, 0.12727925589844868), (0.12727922074646209, 0.12727922276610007), (0.12727922062183225, 0.12727922074646209)]
# C:\Users\benne\AppData\Local\Temp\ipykernel_7412\3374123652.py:7: DeprecationWarning: You are passing x=[0.         0.00252525 0.00505051 0.00757576 0.01010101 0.01262626
#  0.01515152 0.01767677 0.02020202 0.02272727 0.02525253 0.02777778
#  0.03030303 0.03282828 0.03535354 0.03787879 0.04040404 0.04292929
#  0.04545455 0.0479798  0.05050505 0.0530303  0.05555556 0.05808081
#  0.06060606 0.06313131 0.06565657 0.06818182 0.07070707 0.07323232
#  0.07575758 0.07828283 0.08080808 0.08333333 0.08585859 0.08838384
#  0.09090909 0.09343434 0.0959596  0.09848485 0.1010101  0.10353535
#  0.10606061 0.10858586 0.11111111 0.11363636 0.11616162 0.11868687
#  0.12121212 0.12373737 0.12626263 0.12878788 0.13131313 0.13383838
#  0.13636364 0.13888889 0.14141414 0.14393939 0.14646465 0.1489899
#  0.15151515 0.1540404  0.15656566 0.15909091 0.16161616 0.16414141
#  0.16666667 0.16919192 0.17171717 0.17424242 0.17676768 0.17929293
#  0.18181818 0.18434343 0.18686869 0.18939394 0.19191919 0.19444444
#  0.1969697  0.19949495 0.2020202  0.20454545 0.20707071 0.20959596
#  0.21212121 0.21464646 0.21717172 0.21969697 0.22222222 0.22474747
#  0.22727273 0.22979798 0.23232323 0.23484848 0.23737374 0.23989899
#  0.24242424 0.24494949 0.24747475 0.25      ] as a positional argument. Please change your invocation to use keyword arguments. From SciPy 1.14, passing these as positional arguments will result in an error.
#   Integrals.append((float(simpson(v(time,g,w,w0), time)), float(simpson(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
# C:\Users\benne\AppData\Local\Temp\ipykernel_7412\3374123652.py:7: DeprecationWarning: You are passing x=[0.         0.00510204 0.01020408 0.01530612 0.02040816 0.0255102
#  0.03061224 0.03571429 0.04081633 0.04591837 0.05102041 0.05612245
#  0.06122449 0.06632653 0.07142857 0.07653061 0.08163265 0.08673469
#  0.09183673 0.09693878 0.10204082 0.10714286 0.1122449  0.11734694
#  0.12244898 0.12755102 0.13265306 0.1377551  0.14285714 0.14795918
#  0.15306122 0.15816327 0.16326531 0.16836735 0.17346939 0.17857143
#  0.18367347 0.18877551 0.19387755 0.19897959 0.20408163 0.20918367
#  0.21428571 0.21938776 0.2244898  0.22959184 0.23469388 0.23979592
#  0.24489796 0.25      ] as a positional argument. Please change your invocation to use keyword arguments. From SciPy 1.14, passing these as positional arguments will result in an error.
#   Integrals.append((float(simpson(v(time,g,w,w0), time)), float(simpson(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
# C:\Users\benne\AppData\Local\Temp\ipykernel_7412\3374123652.py:7: DeprecationWarning: You are passing x=[0.         0.00125628 0.00251256 0.00376884 0.00502513 0.00628141
#  0.00753769 0.00879397 0.01005025 0.01130653 0.01256281 0.0138191
#  0.01507538 0.01633166 0.01758794 0.01884422 0.0201005  0.02135678
#  0.02261307 0.02386935 0.02512563 0.02638191 0.02763819 0.02889447
#  0.03015075 0.03140704 0.03266332 0.0339196  0.03517588 0.03643216
#  0.03768844 0.03894472 0.04020101 0.04145729 0.04271357 0.04396985
#  0.04522613 0.04648241 0.04773869 0.04899497 0.05025126 0.05150754
#  0.05276382 0.0540201  0.05527638 0.05653266 0.05778894 0.05904523
#  0.06030151 0.06155779 0.06281407 0.06407035 0.06532663 0.06658291
#  0.0678392  0.06909548 0.07035176 0.07160804 0.07286432 0.0741206
#  0.07537688 0.07663317 0.07788945 0.07914573 0.08040201 0.08165829
#  0.08291457 0.08417085 0.08542714 0.08668342 0.0879397  0.08919598
#  0.09045226 0.09170854 0.09296482 0.09422111 0.09547739 0.09673367
#  0.09798995 0.09924623 0.10050251 0.10175879 0.10301508 0.10427136
#  0.10552764 0.10678392 0.1080402  0.10929648 0.11055276 0.11180905
#  0.11306533 0.11432161 0.11557789 0.11683417 0.11809045 0.11934673
#  0.12060302 0.1218593  0.12311558 0.12437186 0.12562814 0.12688442
#  0.1281407  0.12939698 0.13065327 0.13190955 0.13316583 0.13442211
#  0.13567839 0.13693467 0.13819095 0.13944724 0.14070352 0.1419598
#  0.14321608 0.14447236 0.14572864 0.14698492 0.14824121 0.14949749
#  0.15075377 0.15201005 0.15326633 0.15452261 0.15577889 0.15703518
#  0.15829146 0.15954774 0.16080402 0.1620603  0.16331658 0.16457286
#  0.16582915 0.16708543 0.16834171 0.16959799 0.17085427 0.17211055
#  0.17336683 0.17462312 0.1758794  0.17713568 0.17839196 0.17964824
#  0.18090452 0.1821608  0.18341709 0.18467337 0.18592965 0.18718593
#  0.18844221 0.18969849 0.19095477 0.19221106 0.19346734 0.19472362
#  0.1959799  0.19723618 0.19849246 0.19974874 0.20100503 0.20226131
#  0.20351759 0.20477387 0.20603015 0.20728643 0.20854271 0.20979899
#  0.21105528 0.21231156 0.21356784 0.21482412 0.2160804  0.21733668
#  0.21859296 0.21984925 0.22110553 0.22236181 0.22361809 0.22487437
#  0.22613065 0.22738693 0.22864322 0.2298995  0.23115578 0.23241206
#  0.23366834 0.23492462 0.2361809  0.23743719 0.23869347 0.23994975
#  0.24120603 0.24246231 0.24371859 0.24497487 0.24623116 0.24748744
#  0.24874372 0.25      ] as a positional argument. Please change your invocation to use keyword arguments. From SciPy 1.14, passing these as positional arguments will result in an error.
#   Integrals.append((float(simpson(v(time,g,w,w0), time)), float(simpson(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
# C:\Users\benne\AppData\Local\Temp\ipykernel_7412\3374123652.py:7: DeprecationWarning: You are passing x=[0.         0.00062657 0.00125313 0.0018797  0.00250627 0.00313283
#  0.0037594  0.00438596 0.00501253 0.0056391  0.00626566 0.00689223
#  0.0075188  0.00814536 0.00877193 0.0093985  0.01002506 0.01065163
#  0.0112782  0.01190476 0.01253133 0.01315789 0.01378446 0.01441103
#  0.01503759 0.01566416 0.01629073 0.01691729 0.01754386 0.01817043
#  0.01879699 0.01942356 0.02005013 0.02067669 0.02130326 0.02192982
#  0.02255639 0.02318296 0.02380952 0.02443609 0.02506266 0.02568922
#  0.02631579 0.02694236 0.02756892 0.02819549 0.02882206 0.02944862
#  0.03007519 0.03070175 0.03132832 0.03195489 0.03258145 0.03320802
#  0.03383459 0.03446115 0.03508772 0.03571429 0.03634085 0.03696742
#  0.03759398 0.03822055 0.03884712 0.03947368 0.04010025 0.04072682
#  0.04135338 0.04197995 0.04260652 0.04323308 0.04385965 0.04448622
#  0.04511278 0.04573935 0.04636591 0.04699248 0.04761905 0.04824561
#  0.04887218 0.04949875 0.05012531 0.05075188 0.05137845 0.05200501
#  0.05263158 0.05325815 0.05388471 0.05451128 0.05513784 0.05576441
#  0.05639098 0.05701754 0.05764411 0.05827068 0.05889724 0.05952381
#  0.06015038 0.06077694 0.06140351 0.06203008 0.06265664 0.06328321
#  0.06390977 0.06453634 0.06516291 0.06578947 0.06641604 0.06704261
#  0.06766917 0.06829574 0.06892231 0.06954887 0.07017544 0.07080201
#  0.07142857 0.07205514 0.0726817  0.07330827 0.07393484 0.0745614
#  0.07518797 0.07581454 0.0764411  0.07706767 0.07769424 0.0783208
#  0.07894737 0.07957393 0.0802005  0.08082707 0.08145363 0.0820802
#  0.08270677 0.08333333 0.0839599  0.08458647 0.08521303 0.0858396
#  0.08646617 0.08709273 0.0877193  0.08834586 0.08897243 0.089599
#  0.09022556 0.09085213 0.0914787  0.09210526 0.09273183 0.0933584
#  0.09398496 0.09461153 0.0952381  0.09586466 0.09649123 0.09711779
#  0.09774436 0.09837093 0.09899749 0.09962406 0.10025063 0.10087719
#  0.10150376 0.10213033 0.10275689 0.10338346 0.10401003 0.10463659
#  0.10526316 0.10588972 0.10651629 0.10714286 0.10776942 0.10839599
#  0.10902256 0.10964912 0.11027569 0.11090226 0.11152882 0.11215539
#  0.11278195 0.11340852 0.11403509 0.11466165 0.11528822 0.11591479
#  0.11654135 0.11716792 0.11779449 0.11842105 0.11904762 0.11967419
#  0.12030075 0.12092732 0.12155388 0.12218045 0.12280702 0.12343358
#  0.12406015 0.12468672 0.12531328 0.12593985 0.12656642 0.12719298
#  0.12781955 0.12844612 0.12907268 0.12969925 0.13032581 0.13095238
#  0.13157895 0.13220551 0.13283208 0.13345865 0.13408521 0.13471178
#  0.13533835 0.13596491 0.13659148 0.13721805 0.13784461 0.13847118
#  0.13909774 0.13972431 0.14035088 0.14097744 0.14160401 0.14223058
#  0.14285714 0.14348371 0.14411028 0.14473684 0.14536341 0.14598997
#  0.14661654 0.14724311 0.14786967 0.14849624 0.14912281 0.14974937
#  0.15037594 0.15100251 0.15162907 0.15225564 0.15288221 0.15350877
#  0.15413534 0.1547619  0.15538847 0.15601504 0.1566416  0.15726817
#  0.15789474 0.1585213  0.15914787 0.15977444 0.160401   0.16102757
#  0.16165414 0.1622807  0.16290727 0.16353383 0.1641604  0.16478697
#  0.16541353 0.1660401  0.16666667 0.16729323 0.1679198  0.16854637
#  0.16917293 0.1697995  0.17042607 0.17105263 0.1716792  0.17230576
#  0.17293233 0.1735589  0.17418546 0.17481203 0.1754386  0.17606516
#  0.17669173 0.1773183  0.17794486 0.17857143 0.17919799 0.17982456
#  0.18045113 0.18107769 0.18170426 0.18233083 0.18295739 0.18358396
#  0.18421053 0.18483709 0.18546366 0.18609023 0.18671679 0.18734336
#  0.18796992 0.18859649 0.18922306 0.18984962 0.19047619 0.19110276
#  0.19172932 0.19235589 0.19298246 0.19360902 0.19423559 0.19486216
#  0.19548872 0.19611529 0.19674185 0.19736842 0.19799499 0.19862155
#  0.19924812 0.19987469 0.20050125 0.20112782 0.20175439 0.20238095
#  0.20300752 0.20363409 0.20426065 0.20488722 0.20551378 0.20614035
#  0.20676692 0.20739348 0.20802005 0.20864662 0.20927318 0.20989975
#  0.21052632 0.21115288 0.21177945 0.21240602 0.21303258 0.21365915
#  0.21428571 0.21491228 0.21553885 0.21616541 0.21679198 0.21741855
#  0.21804511 0.21867168 0.21929825 0.21992481 0.22055138 0.22117794
#  0.22180451 0.22243108 0.22305764 0.22368421 0.22431078 0.22493734
#  0.22556391 0.22619048 0.22681704 0.22744361 0.22807018 0.22869674
#  0.22932331 0.22994987 0.23057644 0.23120301 0.23182957 0.23245614
#  0.23308271 0.23370927 0.23433584 0.23496241 0.23558897 0.23621554
#  0.23684211 0.23746867 0.23809524 0.2387218  0.23934837 0.23997494
#  0.2406015  0.24122807 0.24185464 0.2424812  0.24310777 0.24373434
#  0.2443609  0.24498747 0.24561404 0.2462406  0.24686717 0.24749373
#  0.2481203  0.24874687 0.24937343 0.25      ] as a positional argument. Please change your invocation to use keyword arguments. From SciPy 1.14, passing these as positional arguments will result in an error.
#   Integrals.append((float(simpson(v(time,g,w,w0), time)), float(simpson(v(np.linspace(t,T,int(0.5 * N)), g,w,w0), np.linspace(t,T,int(0.5 * N))))))
